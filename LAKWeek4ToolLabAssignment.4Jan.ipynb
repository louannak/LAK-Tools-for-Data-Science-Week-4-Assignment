# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <strong>Lou Anna Koehler</strong>
# <br>
# Future Data Scientist
# <br>

# %% [markdown]
# <em>I very much enjoyed the applied math aspects of my university degree in System Science and Engineering.  I see data science as the next step in my career leveraging my Systems Science degree, Computer Science degree, and years of industry experience.  Data Science is a means to bring together all my experience and with the right focus make the world a better place along the way. </em>

# %% [markdown]
# <h3>Create Variables of 4 Numeric Types and Sum The First Three Variables</h3>

# %%
w=32     #int
x=1.6    #float
y=35e10  #scientific float
z=3+5j   #complex
print("w=",w,  type(w))
print("x=",x,  type(x))
print("y=",y,  type(y))
print("z=",z,  type(z))
print("w+x+y =", (w+x+y))
# Out:
# w= 32 <class 'int'>
# x= 1.6 <class 'float'>
# y= 350000000000.0 <class 'float'>
# z= (3+5j) <class 'complex'>
# w+x+y = 350000000033.6

# %% [markdown]
# <h3>My Grocery List with horizontal rule, bulleted, & numbered lists</h3>
#
# ***
# - Milk
# - Sour Cream
# - Butter
# ---
# 1. Eggs
# 2. Flour
# 3. Sugar
#
# <h3>A Table with Strikethrough, Hyperlinks</h3>
#
# | Useful Resource      | Link to Location |
# | ----------- | ----------- |
# | ~~Markdown Syntax~~      | [Basic Markdown](https://www.markdownguide.org/basic-syntax/)       |
# | HTML Syntax   | [HTML Formatting](https://www.w3schools.com/html/html_formatting.asp)        |
#
#
# <h3>Code/Syntax Highlighting with a Block Quote</h3>
#
# > Adding a block quote before the code
#
# ```
#
# function helloworld() {
#   print("hello world!");
# }
#
# ```
#
# <h3>Happy New Year!! </h3>
#
# ![HappyNewYear.jpeg](attachment:08c8290d-0655-4c96-acd9-fe9110b691d8.jpeg)
